# %% [markdown]
# # Spark Streaming

# %%
import os
import sys
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
from pyspark.streaming import StreamingContext
import random
import string

os.environ["JAVA_HOME"] = "/Library/Java/JavaVirtualMachines/temurin-21.jdk/Contents/Home"
os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

spark = SparkSession.builder.appName("Spark Streaming").enableHiveSupport().getOrCreate()
ssc = StreamingContext(spark.sparkContext,3)
print("Driver Python:", sys.executable)
print("Spark:", spark.version)
# Out:
# Driver Python: /Users/darvikkunalbanda/DataEngineering/.venv/bin/python
# Spark: 4.1.2
# /Users/darvikkunalbanda/DataEngineering/.venv/lib/python3.12/site-packages/pyspark/streaming/context.py:72: FutureWarning: DStream is deprecated as of Spark 3.4.0. Migrate to Structured Streaming.
#   warnings.warn(

# %%
#data = ["hello", "world", "spark", "streaming"]
rddQueue = []

# %%
for i in range(3):
    data = ["hello", "world", "spark", "streaming"]
    data = list(map(lambda x: x+random.choice(string.ascii_letters + string.digits + string.punctuation),data))
    rddQueue += [spark.sparkContext.parallelize(data)]

# %%
dstreams = ssc.queueStream(rddQueue)

# %%
# word count

words = dstreams.flatMap(lambda line: line.split(" "))
wordCounts = words.map(lambda word: (word,1)).reduceByKey(lambda x, y:x+y)
wordCounts.pprint()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[8], line 5
#       1 # word count
#       2
#       3 words = dstreams.flatMap(lambda line: line.split(" "))
#       4 wordCounts = words.map(lambda word: (word,1)).reduceByKey(lambda x, y:x+y)
# ----> 5 wordCounts.pprint()
#
# File ~/DataEngineering/.venv/lib/python3.12/site-packages/pyspark/streaming/dstream.py:264, in DStream.pprint(self, num)
#     261         print("...")
#     262     print("")
# --> 264 self.foreachRDD(takeAndPrint)
#
# File ~/DataEngineering/.venv/lib/python3.12/site-packages/pyspark/streaming/dstream.py:241, in DStream.foreachRDD(self, func)
#     239 assert self._ssc._jvm is not None
#     240 api = self._ssc._jvm.PythonDStream
# --> 241 api.callForeachRDD(self._jdstream, jfunc)
#
# ...

# %%
ssc.start()
ssc.awaitTermination()
ssc.stop()
# Out:
# -------------------------------------------
# Time: 2026-06-23 10:54:21
# -------------------------------------------
# ('streamingW', 1)
# ('helloK', 1)
# ('worldJ', 1)
# ('sparki', 1)
#
# -------------------------------------------
# Time: 2026-06-23 10:54:24
# -------------------------------------------
# ('worldY', 1)
# ('streamingJ', 1)
# ('spark&', 1)
# ('hello`', 1)
#
# -------------------------------------------
# Time: 2026-06-23 10:54:27
# -------------------------------------------
# ('world_', 1)
# ('spark(', 1)
# ('helloL', 1)
# ('streamingq', 1)
#
# -------------------------------------------
# Time: 2026-06-23 10:54:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2026-06-23 10:54:33
# -------------------------------------------
#
# -------------------------------------------
# Time: 2026-06-23 10:54:36
# -------------------------------------------
#
# -------------------------------------------
# ...
